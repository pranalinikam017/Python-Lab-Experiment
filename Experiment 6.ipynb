# %%
d1 = { "name":"Jungkook",
      "Roll no" : 21,
      "Branch":"I.T",
      "c.g.p.a": 9.8
      }
print("Dictionary of Student details:",d1)
# Out:
# Dictionary of Student details: {'name': 'Jungkook', 'Roll no': 21, 'Branch': 'I.T', 'c.g.p.a': 9.8}

# %%
d1 ={}

for i in  range (1, 6):
    d1[i]= i**2

print(d1)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
s1 = {"jin" : 89,
      "Jimin" : 90,
      "Jungkook" : 96,
      "V" : 92
      }
top_student = ""
max_marks = 0
for i in s1:
     if(s1[i] > max_marks):
       max_marks = s1[i]
       top_student = i


print(top_student)
# Out:
# Jungkook

# %%
student = {
    "name": "Rahul",
    "age": 20,
    "course": "BCA"
}

word_count = {
    "this": 2,
    "is": 1,
    "python": 1
}

merged_dict = student | word_count
print(merged_dict)
# Out:
# {'name': 'Rahul', 'age': 20, 'course': 'BCA', 'this': 2, 'is': 1, 'python': 1}

# %%
d = {"Rahul":85, "Amit":92, "Sneha":88}

# Sort by key
sorted_by_key = {k: d[k] for k in sorted(d)}
print("Sorted by key:", sorted_by_key)

# Sort by value
sorted_by_value = {k: v for k, v in sorted(d.items(), key=lambda item: item[1])}
print("Sorted by value:", sorted_by_value)
# Out:
# Sorted by key: {'Amit': 92, 'Rahul': 85, 'Sneha': 88}
# Sorted by value: {'Rahul': 85, 'Sneha': 88, 'Amit': 92}

# %%
d1 = { "name":"Jungkook",
      "Roll no" : 21,
      "Branch":"I.T",
      "c.g.p.a": 9.8
      }
print("Dictionary of Student details:",d1)

d1['gender'] = 'male'
d1['year'] = 2026

print("\nAfter using add operation:",d1)

del d1['Branch']

print("\nAfter using delete operation:",d1)
# Out:
# Dictionary of Student details: {'name': 'Jungkook', 'Roll no': 21, 'Branch': 'I.T', 'c.g.p.a': 9.8}
#
# After using add operation: {'name': 'Jungkook', 'Roll no': 21, 'Branch': 'I.T', 'c.g.p.a': 9.8, 'gender': 'male', 'year': 2026}
#
# After using delete operation: {'name': 'Jungkook', 'Roll no': 21, 'c.g.p.a': 9.8, 'gender': 'male', 'year': 2026}

# %%
d1 = {1 : "RM", 2:"Jin", 3:"J-hope" , 4:"Suga",5:"Jimin",6:"V", 7:"Jungkook"}

print("Keys: ")
for key in d1.keys():
    print(key)


print("Values: ")
for value in d1.values():
    print(value)

print("Dictionary: ",d1)
# Out:
# Keys:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# Values:
# RM
# Jin
# J-hope
# Suga
# Jimin
# V
# Jungkook
# Dictionary:  {1: 'RM', 2: 'Jin', 3: 'J-hope', 4: 'Suga', 5: 'Jimin', 6: 'V', 7: 'Jungkook'}

# %%
s1 = input("Enter one string:")

print(s1.lower())

st1 = s1.split()
print(st1)

count = 0
for i in st1:
    count+= 1

print(count)
# Out:
# Enter one string: hello world
# hello world
# ['hello', 'world']
# 2
